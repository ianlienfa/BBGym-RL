# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
def read_loss_file(filename):  
    f = open(filename, "r")
    str = f.readline()
    li = list(str.split(", "))
    li = li[:-1]
    li = [float(i) for i in li]
    return li

# %%
pi_loss = read_loss_file("../saved_model/pi_loss.txt")
q_loss = read_loss_file("../saved_model/q_loss.txt")
rewards = read_loss_file("../saved_model/rewards.txt")
inf_rewards = read_loss_file("../saved_model/inf_rewards.txt")

# %%
# plot two figures
plt.plot(pi_loss)
plt.ylabel('pi loss')
plt.show()

# %%
# plot two figures
# raw_q_loss = q_loss
# q_loss = []
# i = 10
# tmp = 0
# for it in range(len(raw_q_loss)):
#     if(i != 0):
#         tmp += raw_q_loss[it]
#     else:
#         q_loss.append(tmp)
#         tmp = 0
#         i = 10
#     i -= 1

# print(len(raw_q_loss))
        
plt.plot(q_loss)
plt.ylabel('q loss')
plt.show()

# %%
# raw_rewards = rewards
# rewards = []
# i = 10
# tmp = 0
# for it in range(len(raw_rewards)):
#     if(i != 0):
#         tmp += raw_rewards[it]
#     else:
#         rewards.append(tmp)
#         tmp = 0
#         i = 10
#     i -= 1

plt.plot(rewards)
axis = plt.gca()
axis.set_ylim([-10, 3])
plt.ylabel('rewards')
plt.show()

# %%
# raw_rewards = inf_rewards
# inf_rewards = []
# i = 1
# tmp = 0
# for it in range(len(raw_rewards)):
#     if(i != 0):
#         tmp += raw_rewards[it]
#     else:
#         inf_rewards.append(tmp)
#         tmp = 0
#         i = 1
#     i -= 1

plt.plot(inf_rewards)
axis = plt.gca()
axis.set_ylim([-10, 3])
plt.ylabel('inf rewards')
plt.show()

# %%
print(inf_rewards)
# Out:
# [-0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739, -0.242739]
